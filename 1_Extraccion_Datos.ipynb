# %% [markdown]
# <a href="https://colab.research.google.com/github/EddiRafael/Clase_desarrollo_proyectos/blob/main/1_Extraccion_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerias requeridas 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io

# %%
#cargar archivo csv desde equipo 
from google.colab import files 
files.upload()

# %%
#convertir en dataframe 
df= pd.read_csv("file.csv")
df

# %%
#imprimimos las primeras filas o registros del dataframe 
df.head(5)

# %%
#filtro por objeto 
filtro1=df[df["Entidad_Federativa"]=="Baja California"]
filtro1

# %%
#filtro por filas 
filtro2= df.iloc[0:99,: ]
filtro2=df.iloc[[1000, 2000, 3000], : ]
filtro2

# %%
#filtro por columnas 
#filtro3= df.iloc[ : , 4:6]
filtro3= df.iloc[ : , [1,4,6]] #columnas consecutivas 
filtro3

# %%
#filtro por columnas y filas
filtro_mix= df.iloc[ [10,20,50] , 2:5]
#filtro3= df.iloc[ : , [1,4,6]] #columnas no consecutivas 
filtro_mix

# %%
#filtro de filas vs columnas 
#paso 1: leemos el contenido del archivo 
from google.colab import files 
uploaded= files.upload()
df= pd.read_csv(io.BytesIO(uploaded['file.csv']), index_col=2)
df
# Out:
#      <input type="file" id="files-65b9a9bc-5c02-4778-b734-e8d110837f1d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-65b9a9bc-5c02-4778-b734-e8d110837f1d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#paso2: aplicamos filtro de filas vs columnas 
filtro4= df.loc[["Puebla","Oaxaca","Veracruz","Guerrero"],["Poblacion_ocupada_en_la_industria_manufacturera"]]
filtro4

# %%
#filtro por cabecera
filtro5=df.head()
filtro5
# Out:
#                     Periodo  Trimestre     Sexo  \
# Entidad_Federativa
# Nacional               2005          1  Hombres
# Nacional               2005          1  Mujeres
# Aguascalientes         2005          1  Hombres
# Aguascalientes         2005          1  Mujeres
# Baja California        2005          1  Hombres
#
#                    Poblacion_ocupada_en_la_industria_manufacturera  \
# Entidad_Federativa
# Nacional                                                   4384907
# Nacional                                                   2690296
# Aguascalientes                                               56407
# Aguascalientes                                               28430
# Baja California                                             167651
#
#                    Poblaci n_ocupada  \
# Entidad_Federativa
# Nacional                    26597801
# Nacional                    14843275
# Aguascalientes                246177
# Aguascalientes                145656
# ...

# %% [markdown]
# FILTROS BASICOS PARA VARIABLES CUANTITATIVAS

# %%
#filtro por comparacion 
filtro6= df[df["Periodo"] > 2006]
filtro6
# Out:
#                     Periodo  Trimestre     Sexo  \
# Entidad_Federativa
# Nacional               2007          1  Hombres
# Nacional               2007          1  Mujeres
# Aguascalientes         2007          1  Hombres
# Aguascalientes         2007          1  Mujeres
# Baja California        2007          1  Hombres
# ...                     ...        ...      ...
# Veracruz               2022          1  Mujeres
# Yucat n                2022          1  Hombres
# Yucat n                2022          1  Mujeres
# Zacatecas              2022          1  Hombres
# Zacatecas              2022          1  Mujeres
#
#                    Poblacion_ocupada_en_la_industria_manufacturera  \
# Entidad_Federativa
# Nacional                                                   4495811
# Nacional                                                   2798066
# Aguascalientes                                               59177
# Aguascalientes                                               31485
# ...
